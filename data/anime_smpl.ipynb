# %%
import pandas as pd

# %%
df = pd.read_csv('anime.csv')
df
# Out:
#        MAL_ID                             Name    Score  \
# 0           1                     Cowboy Bebop     8.78
# 1           5  Cowboy Bebop: Tengoku no Tobira     8.39
# 2           6                           Trigun     8.24
# 3           7               Witch Hunter Robin     7.27
# 4           8                   Bouken Ou Beet     6.98
# ...       ...                              ...      ...
# 17557   48481  Daomu Biji Zhi Qinling Shen Shu  Unknown
# 17558   48483                     Mieruko-chan  Unknown
# 17559   48488  Higurashi no Naku Koro ni Sotsu  Unknown
# 17560   48491      Yama no Susume: Next Summit  Unknown
# 17561   48492                    Scarlet Nexus  Unknown
#
#                                                   Genres  \
# 0        Action, Adventure, Comedy, Drama, Sci-Fi, Space
# 1                  Action, Drama, Mystery, Sci-Fi, Space
# 2      Action, Sci-Fi, Adventure, Comedy, Drama, Shounen
# 3      Action, Mystery, Police, Supernatural, Drama, ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17562 entries, 0 to 17561
# Data columns (total 35 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MAL_ID         17562 non-null  int64
#  1   Name           17562 non-null  object
#  2   Score          17562 non-null  object
#  3   Genres         17562 non-null  object
#  4   English name   17562 non-null  object
#  5   Japanese name  17562 non-null  object
#  6   Type           17562 non-null  object
#  7   Episodes       17562 non-null  object
#  8   Aired          17562 non-null  object
#  9   Premiered      17562 non-null  object
#  10  Producers      17562 non-null  object
#  11  Licensors      17562 non-null  object
#  12  Studios        17562 non-null  object
#  13  Source         17562 non-null  object
#  14  Duration       17562 non-null  object
#  15  Rating         17562 non-null  object
#  16  Ranked         17562 non-null  object
# ...

# %%
# animation unique counts
len(set(df.iloc[:,0]))
# Out:
# 17562

# %%
# name counts
print(len(set(df['Name'])))
print(len(df[df['Name']=='Unknown']))
# Out:
# 17558
# 0

# %%
# name counts
print(len(set(df['English name'])))
print(len(df[df['English name']=='Unknown']))
# Out:
# 6831
# 10565

# %%
# name counts
print(len(set(df['Japanese name'])))
print(len(df[df['Japanese name']=='Unknown']))
# Out:
# 16679
# 48

# %%
# 결론적으로 꽉차있고, 영어로 된 Name만 일단 적용. 일본어 검색도 호환되게는 고민이 더필요

# %%
for i in df.columns.tolist():
    print("#" + str(i))
    print("unique counts : " + str(len(set(df[i]))))
    print("Unknown counts : "+str(len(df[df[i]=='Unknown'])))
# Out:
# #MAL_ID
# unique counts : 17562
# Unknown counts : 0
# #Name
# unique counts : 17558
# Unknown counts : 0
# #Score
# unique counts : 533
# Unknown counts : 5141
# #Genres
# unique counts : 5034
# Unknown counts : 63
# #English name
# unique counts : 6831
# Unknown counts : 10565
# #Japanese name
# unique counts : 16679
# Unknown counts : 48
# #Type
# unique counts : 7
# Unknown counts : 37
# #Episodes
# unique counts : 201
# Unknown counts : 516
# #Aired
# unique counts : 11947
# Unknown counts : 309
# #Premiered
# unique counts : 231
# Unknown counts : 12817
# #Producers
# unique counts : 3783
# Unknown counts : 7794
# #Licensors
# unique counts : 231
# Unknown counts : 13616
# #Studios
# unique counts : 1090
# Unknown counts : 7079
# #Source
# unique counts : 16
# Unknown counts : 3567
# #Duration
# unique counts : 313
# Unknown counts : 555
# #Rating
# unique counts : 7
# Unknown counts : 688
# #Ranked
# unique counts : 10490
# Unknown counts : 1762
# #Popularity
# ...

# %%
pd.set_option('display.max_columns', None)
df.head()
# Out:
#    MAL_ID                             Name Score  \
# 0       1                     Cowboy Bebop  8.78
# 1       5  Cowboy Bebop: Tengoku no Tobira  8.39
# 2       6                           Trigun  8.24
# 3       7               Witch Hunter Robin  7.27
# 4       8                   Bouken Ou Beet  6.98
#
#                                               Genres            English name  \
# 0    Action, Adventure, Comedy, Drama, Sci-Fi, Space            Cowboy Bebop
# 1              Action, Drama, Mystery, Sci-Fi, Space  Cowboy Bebop:The Movie
# 2  Action, Sci-Fi, Adventure, Comedy, Drama, Shounen                  Trigun
# 3  Action, Mystery, Police, Supernatural, Drama, ...      Witch Hunter Robin
# 4          Adventure, Fantasy, Shounen, Supernatural  Beet the Vandel Buster
#
#                       Japanese name   Type Episodes  \
# 0                         カウボーイビバップ     TV       26
# 1                    カウボーイビバップ 天国の扉  Movie        1
# ...

# %%
# 일단 간단한 정보만 활용해보자
df_simple = df[['MAL_ID','Name','Score','Genres']].copy()

# %%
df_simple['Score'] = df_simple['Score'].replace('Unknown',0)

# %%
df_simple['Genres'] = df_simple['Genres'].replace('Unknown','etc')

# %%
df_simple
# Out:
#        MAL_ID                             Name Score  \
# 0           1                     Cowboy Bebop  8.78
# 1           5  Cowboy Bebop: Tengoku no Tobira  8.39
# 2           6                           Trigun  8.24
# 3           7               Witch Hunter Robin  7.27
# 4           8                   Bouken Ou Beet  6.98
# ...       ...                              ...   ...
# 17557   48481  Daomu Biji Zhi Qinling Shen Shu     0
# 17558   48483                     Mieruko-chan     0
# 17559   48488  Higurashi no Naku Koro ni Sotsu     0
# 17560   48491      Yama no Susume: Next Summit     0
# 17561   48492                    Scarlet Nexus     0
#
#                                                   Genres
# 0        Action, Adventure, Comedy, Drama, Sci-Fi, Space
# 1                  Action, Drama, Mystery, Sci-Fi, Space
# 2      Action, Sci-Fi, Adventure, Comedy, Drama, Shounen
# 3      Action, Mystery, Police, Supernatural, Drama, ...
# ...

# %%
set(df_simple[df_simple.apply(lambda x: ',' not in x['Genres'], axis=1)]['Genres'])
# Out:
# {'Action',
#  'Adventure',
#  'Cars',
#  'Comedy',
#  'Dementia',
#  'Demons',
#  'Drama',
#  'Ecchi',
#  'Fantasy',
#  'Game',
#  'Harem',
#  'Hentai',
#  'Historical',
#  'Horror',
#  'Josei',
#  'Kids',
#  'Magic',
#  'Martial Arts',
#  'Mecha',
#  'Military',
#  'Music',
#  'Mystery',
#  'Parody',
#  'Police',
#  'Psychological',
#  'Romance',
#  'Samurai',
#  'School',
#  'Sci-Fi',
#  'Seinen',
#  'Shoujo',
#  'Shounen',
#  'Shounen Ai',
#  'Slice of Life',
#  'Space',
#  'Sports',
#  'Supernatural',
#  'Thriller',
#  'Vampire',
#  'Yaoi',
#  'etc'}

# %%
# df_simple['Genres'] = df_simple['Genres'].apply(lambda x: x.strip().split(','))

# %%
df_simple
# Out:
#        MAL_ID                             Name Score  \
# 0           1                     Cowboy Bebop  8.78
# 1           5  Cowboy Bebop: Tengoku no Tobira  8.39
# 2           6                           Trigun  8.24
# 3           7               Witch Hunter Robin  7.27
# 4           8                   Bouken Ou Beet  6.98
# ...       ...                              ...   ...
# 17557   48481  Daomu Biji Zhi Qinling Shen Shu     0
# 17558   48483                     Mieruko-chan     0
# 17559   48488  Higurashi no Naku Koro ni Sotsu     0
# 17560   48491      Yama no Susume: Next Summit     0
# 17561   48492                    Scarlet Nexus     0
#
#                                                   Genres
# 0        Action, Adventure, Comedy, Drama, Sci-Fi, Space
# 1                  Action, Drama, Mystery, Sci-Fi, Space
# 2      Action, Sci-Fi, Adventure, Comedy, Drama, Shounen
# 3      Action, Mystery, Police, Supernatural, Drama, ...
# ...

# %%
df_simple.to_csv('anime_smpl.csv',index=False,encoding='utf-8-sig')
